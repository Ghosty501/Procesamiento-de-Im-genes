# %%
import math
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Transformación logaritmica

# %%
math.log(0+1)
# Out:
# 0.0

# %%
math.log10(255)
# log solo, aplica el logaritmo natural y toma como base e
# log10 aplica el logatimo con base 10
# Out:
# 2.406540180433955

# %%
img = cv.imread('c:/Users/arman/Downloads/aero1.jpg', 0)

# %%
plt.imshow(img, "gray")
plt.show()

# %%
fil, col = img.shape

# %%
C = 255

# %%
img_log

# %%
np.hstack(img, img_log)

# %%
plt.imshow(np.hstack(img, img_log), "gray")
plt.show()

# %% [markdown]
# # Transformaciones gamma

# %%
100 ** 2
# Out:
# 10000

# %%
img_gamma = img.copy()

# %%
gamma=2
for f in range(fil):
    for c in range(col):
        img_gamma[f, c]= img[f,c] ** gamma

# %%
plt.imshow(img_gamma, "gray")
plt.show()

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img_float = img.astype(np.float32)

# %%
img_float = img_float.astype(np.uint8)
