# %%
import cv2 as cv 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv.imread('f:/Imagenes/excavator-824655_1280.jpg', 0)

# %%
plt.imshow(img, "gray")
plt.show()

# %%
histograma = cv.calcHist([img], [0], None, [256], (0, 256))

#Imagen
#
# La máscara que se utiliza
# Tamaño del histograma
# De dónde a dónde vas a tomar tus valores

# %%
type(histograma)
# Out:
# numpy.ndarray

# %%
histograma.shape
# Out:
# (256, 1)

# %%
# Esto es incorrecto
plt.imshow(histograma)
plt.show()

# %%
# Esto es lo correcto

plt.plot(histograma)
plt.show()

# %% [markdown]
# ----
# ## A color

# %%
img = cv.imread('c:/Users/arman/Downloads/WindowsLogo.jpg')

# %%
img.shape
# Out:
# (240, 320, 3)

# %%
histograma_b = cv.calcHist([img], [0], None, [256], (0, 256))

# %%
plt.plot(histograma_b, "blue")
plt.show()

# %%
histograma_g = cv.calcHist([img], [0], None, [256], (0, 256))

# %%
plt.plot(histograma_g, "Green")
plt.show()

# %%
histograma_r= cv.calcHist([img], [0], None, [256], (0, 256))

# %%
plt.plot(histograma_r, "Red")
plt.show()

# %%
colores = ["b", "g", "r"]

# %%
for i in range(len(colores)):
    histograma_b = cv.calcHist([img], [n], None, [256], (0, 256))
    plt.plot(tmp, i)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 for i in range(len(colores)):
# ----> 2     histograma_b = cv.calcHist([img], [n], None, [256], (0, 256))
#       3     plt.plot(tmp, i)
#       4 plt.show()
#
# NameError: name 'n' is not defined

# %%
for cuenta, valor in enumerate(colores):
    print(f"Cuenta = {cuenta} Valor= {valor}")
# Out:
# Cuenta=  0 Valor= b
# Cuenta=  1 Valor= g
# Cuenta=  2 Valor= r
